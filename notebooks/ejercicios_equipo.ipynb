# %% [markdown]
# # Ejercicios — Capítulo X: [Tema]
# **Equipo:** <nombre-equipo>
#
# Estos ejercicios los va a resolver el resto de la clase. No debe ser una réplica de los ejemplos del libro: deben requerir aplicar los conceptos sobre nuestro dataset o sobre preguntas al estilo certificación.
#
# Progresión sugerida: 2-3 ejercicios simples, 2-3 intermedios, 1-2 de integración/desafío.

# %% [markdown]
# ## Ejercicio 1 (básico)
#
# _Consigna..._

# %%
# Espacio para resolver

# %% [markdown]
# **Verificación esperada:** _describir qué resultado o shape debería obtenerse, para que el estudiante pueda autoevaluarse._

# %% [markdown]
# ## Ejercicio 2 (intermedio)
#
# _Consigna..._

# %%
# Espacio para resolver

# %% [markdown]
# ## Desafío (opcional / para casa)
#
# _Consigna más abierta, requiere combinar varios conceptos del capítulo._

# %%
# Espacio para resolver
